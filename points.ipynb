# %%
import cv2
import dlib
import numpy as np
from matplotlib import pyplot as plt

import utils.select_util

# %%
img = cv2.imread("images/test1.jpg")
plt.imshow(img[:, :, [2, 1, 0]])

# %%
# press Q to leave!
pts = utils.select_util.get_points(img)
print(pts)
# Out:
# [(240, 382), (281, 355), (317, 355), (356, 380), (315, 390), (284, 386)]
